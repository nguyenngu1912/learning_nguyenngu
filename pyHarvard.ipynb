# %%
# Problem set 0 # 1 (Cs50 Harvard)
x = input()
print(x.lower())
# Out:
# hell no

# %%
# Problem set 0 # 2 (Cs50 Harvard)
x = input()
print(x.replace(" ","..."))
# Out:
# This...is...cs50.

# %%
# Problem set 0 # 3 (Cs50 Harvard)

# convert str to icon
def convert():
    x = input()
    print(x.replace(":)","🙂").replace(":(","🙁"))
def main():
    convert()    

main()
# Out:
# Hello 🙂 bnuy 🙁

# %%
# Problem set 0 # 4 (Cs50 Harvard)
c = 300000000
def enstein():
    m = int(input())
    return m * c * c
enstein()
# Out:
# 90000000000000000

# %%
# Problem set 0 # 5 (Cs50 Harvard)
def main():
    dollars = dollars_to_float(input("How much was the meal? "))
    percent = percent_to_float(input("What percentage would you like to tip? "))
    tip = dollars * percent
    print(f"Leave ${tip:.2f}")


def dollars_to_float(d):
    d = float(d.replace("$",""))
    return d

def percent_to_float(p):
    p = float(p.replace("%","")) 
    return float (p/100)

main()
# Out:
# Leave $18.00

# %%
# Problem set 1 # 1 (Cs50 Harvard)

q = input("What is the Answer to the Great Question of Life, the Universe, and Everything? ").lower().strip().replace(" ","")

if q == "42" or q == "forty-two" or q == "fortytwo":
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
# Problem set 1 # 2 (Cs50 Harvard)
p = input("Greeting: ").strip().lower().replace(" ","")

if p[0:5] == "hello":
    print("$0") 
elif p[0] == "h":
    print("$20")
else:
    print("$100")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 6
#       4 if p[0:5] == "hello":
#       5     print("$0")
# ----> 6 elif p[0] == "h":
#       7     print("$20")
#       8 else:
#
# IndexError: string index out of range

# %%
# Problem set 1 # 3 (Cs50 Harvard)
x = input("File name: ").replace(" ","").lower().strip()

if x[x.find(".") + 1:] == "jpg" :
    print("image/jpg")
elif x[x.find(".") + 1:] == "gif" :
    print("image/gif")
elif x[x.find(".") + 1:] == "jpeg" :
    print("image/jpeg")
elif x[x.find(".") + 1:] == "png" :
    print("image/png")    
elif x[x.find(".") + 1:] == "pdf" :
    print("application/pdf")    
elif x[x.find(".") + 1:] == "txt" :
    print("text/plain")    
elif x[x.find(".") + 1:] == "zip" :
    print("application/x-zip-compressed")    
else:
    print("application/octet-stream ")
# Out:
# application/x-zip-compressed

# %%
# Problem set 1 # 4 (Cs50 Harvard)
a = input("Expression: ").strip()

if a is not None:
    x = int(a.replace(" ","")[0])
    y = a.replace(" ","")[1]
    z = int(a.replace(" ","")[2])
 
    if y == "+":
        print(x + z)
    elif y == "-":    
        print(x - z)
    elif y == "*":    
        print(x * z)  
    elif y == "/":    
        print(x / z)     
    else:
        print("y is not regconized")    
else:
    pass
# Out:
# 3

# %%
# Problem set 1 # 5 (Cs50 Harvard)
# breakfast 7:00 to 8:00, lunch: 12:00 and 13:00, dinner: 18:00 and 19:00
# challenge: support a.m. and p.m. (12-hour times)
def main():
    x = input("What time is it? ").strip().replace(" ","")
    time = convert(x)
    if time == "invalid minutes":
        print("ValueError")
    else:
        if 7 <= round(time,1) <= 8:
            print("breakfast time")
        elif 12 <= round(time,1) <= 13:
            print("lunch time")
        elif 18 <= round(time,1) <= 19:
            print("dinner time") 
        else:
            pass

def convert(time):
    xx = time[-2:]
    if xx == "pm":
        time = time.split(xx)[0]
        hours, minutes = time.split(":")
        hours = int(hours) + 12
    else:
        time = time.split(xx)[0]
        hours, minutes = time.split(":")
    
    if 0 <= int(minutes) <= 60:      
        return int(hours) + float(int(minutes)/60)
    else:
        return "invalid minutes"

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 35
#      32         return "invalid minutes"
#      34 if __name__ == "__main__":
# ---> 35     main()
#
# Cell In[1], line 6, in main()
#       4 def main():
#       5     x = input("What time is it? ").strip().replace(" ","")
# ----> 6     time = convert(x)
#       7     if time == "invalid minutes":
#       8         print("ValueError")
#
# Cell In[1], line 29, in convert(time)
#      26     time = time.split(xx)[0]
#      27     hours, minutes = time.split(":")
# ---> 29 if 0 <= int(minutes) <= 60:
#      30     return int(hours) + float(int(minutes)/60)
#      31 else:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Problem set 2 # 1 (Cs50 Harvard)

# firstName ==> first_name

camel_case = input("CamelCase: ").replace(" ","").strip()
list_item = list(camel_case)

if camel_case.islower():
        print(camel_case)
else:
    for i in range(0, len(list_item)):    
        if list_item[i].isupper():
            snake_case = camel_case.replace(list_item[i], "_" + list_item[i].lower())
            camel_case = snake_case
        else:
            pass
    print("snake_case: ",snake_case)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 17
#      15     else:
#      16         pass
# ---> 17 print("snake_case: ",snake_case)
#
# NameError: name 'snake_case' is not defined

# %%
x = " test"
def myfunc1():
  x = "Jane"
  def myfunc2():
    # global x
    nonlocal x
    x = "hello"
  myfunc2()
  return x

print(myfunc1())
# Out:
# None
